# %% [markdown]
# <a href="https://colab.research.google.com/github/andrethydavid/Archivo/blob/master/pokemon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_estilos = pd.read_csv('/content/Pokemon.csv',sep=',',header=0)

# %%
df_estilos[0:4]
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False

# %% [markdown]
# ### Loc

# %%
df_estilos.loc[:]
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# ### Filtrar por columnas

# %%
df_estilos[['Name','Legendary']]
# Out:
#                       Name  Legendary
# 0                Bulbasaur      False
# 1                  Ivysaur      False
# 2                 Venusaur      False
# 3    VenusaurMega Venusaur      False
# 4               Charmander      False
# ..                     ...        ...
# 795                Diancie       True
# 796    DiancieMega Diancie       True
# 797    HoopaHoopa Confined       True
# 798     HoopaHoopa Unbound       True
# 799              Volcanion       True
#
# [800 rows x 2 columns]

# %%
df_estilos.loc[0:4, ['Name','Legendary']]
# Out:
#                     Name  Legendary
# 0              Bulbasaur      False
# 1                Ivysaur      False
# 2               Venusaur      False
# 3  VenusaurMega Venusaur      False
# 4             Charmander      False

# %%
df_estilos.loc[:, ['Speed']] * -1
# Out:
#      Speed
# 0      -45
# 1      -60
# 2      -80
# 3      -80
# 4      -65
# ..     ...
# 795    -50
# 796   -110
# 797    -70
# 798    -80
# 799    -70
#
# [800 rows x 1 columns]

# %% [markdown]
# ### Iloc

# %%
df_estilos.iloc[:,0:3]
# Out:
#        #                   Name   Type 1
# 0      1              Bulbasaur    Grass
# 1      2                Ivysaur    Grass
# 2      3               Venusaur    Grass
# 3      3  VenusaurMega Venusaur    Grass
# 4      4             Charmander     Fire
# ..   ...                    ...      ...
# 795  719                Diancie     Rock
# 796  719    DiancieMega Diancie     Rock
# 797  720    HoopaHoopa Confined  Psychic
# 798  720     HoopaHoopa Unbound  Psychic
# 799  721              Volcanion     Fire
#
# [800 rows x 3 columns]

# %%
df_estilos.iloc[1,3] * -1
# Out:
# ''
